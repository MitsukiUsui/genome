# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
def myplot(df):
    xClm="count_sim"
    yClm="count_real"
    plt.figure(figsize=(8,8))
    sns.regplot(xClm,yClm,data=df,fit_reg=False)
    plt.plot([0,6],[0,6],"k:")
    plt.xlim([0,2.7])
    plt.ylim([0,2.7])
    plt.xlabel("")
    plt.ylabel("")
    plt.tick_params(labelsize=15)
    plt.show()

# %%
countFilepath="summarize_count.csv"
count_df=pd.read_csv(countFilepath)
print(count_df.shape)
count_df.head()
# Out:
# (1615, 3)
#      taxid  count_real  count_sim
# 0   429572    0.425893   0.427635
# 1  1434120    0.463257   0.442056
# 2   188937    0.448898   0.429019
# 3  1054217    1.094285   0.843878
# 4  1434123    0.410412   0.401882

# %%
xClm="count_sim"
yClm="count_real"
g=sns.jointplot(xClm, yClm, data=count_df,stat_func=None)
g.ax_joint.plot(range(7), ':k')
g.ax_joint.set_xlim([0,2.7])
g.ax_joint.set_ylim([0,2.7])
g.ax_joint.set_xlabel("")
g.ax_joint.set_ylabel("")

#g.set(xlabel="",ylabel="")
plt.show()

# %%
myplot(count_df)

# %%
lookupFilepath="../speciespick/picked_assembly_summary_code.csv"
lookup_df=pd.read_csv(lookupFilepath)
print(lookup_df.shape)
lookup_df.head()
# Out:
# (1615, 8)
#      asm_name assembly_accession   domain                ftp_basename  \
# 0   ASM2238v1    GCF_000022385.1  archaea   GCF_000022385.1_ASM2238v1
# 1  ASM97008v1    GCF_000970085.1  archaea  GCF_000970085.1_ASM97008v1
# 2    ASM734v1    GCF_000007345.1  archaea    GCF_000007345.1_ASM734v1
# 3  ASM35030v1    GCF_000350305.1  archaea  GCF_000350305.1_ASM35030v1
# 4  ASM96990v1    GCF_000969905.1  archaea  GCF_000969905.1_ASM96990v1
#
#                                             ftp_path  \
# 0  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000...
# 1  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000...
# 2  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000...
# 3  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000...
# 4  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000...
#
#                       organism_name    taxid  genetic_code
# 0    Sulfolobus islandicus L.S.2.15   429572            11
# 1      Methanosarcina siciliae T4/M  1434120            11
# 2    Methanosarcina acetivorans C2A   188937            11
# 3  Thermoplasmatales archaeon BRNA1  1054217            11
# 4    Methanosarcina vacuolata Z-761  1434123            11

# %%
compFilepath="../preprocess/out/summary_composition.csv"
comp_df=pd.read_csv(compFilepath)
comp_df=comp_df[comp_df["dna_type"]=="chromosome"]#exclude plasmid
print(comp_df.shape)
comp_df.head()
# Out:
# (1615, 100)
#                  ftp_basename    dna_type       G+C  num_ambiguous  \
# 0   GCF_000022385.1_ASM2238v1  chromosome  0.351110              0
# 1  GCF_000970085.1_ASM97008v1  chromosome  0.429404              0
# 2    GCF_000007345.1_ASM734v1  chromosome  0.426809              0
# 3  GCF_000350305.1_ASM35030v1  chromosome  0.583030              0
# 4  GCF_000969905.1_ASM96990v1  chromosome  0.397795              0
#
#    per_ambiguous        A        C        G        T   B   ...      TCG  \
# 0            0.0   888038   475131   485602   887501 NaN   ...    14898
# 1            0.0  1420708  1073050  1081510  1442290 NaN   ...    52223
# 2            0.0  1638004  1228410  1226378  1658700 NaN   ...    60400
# 3            0.0   306724   427580   424288   302513 NaN   ...    37083
# 4            0.0  1340341   902862   889505  1373044 NaN   ...    39862
#
#       TCT     TGA    TGC    TGG    TGT     TTA     TTC     TTG     TTT
# 0   59802   45239  25365  35234  33745   95524   58476   47604   96167
# 1   96142   93249  75156  63340  72350   91433  129173   89002  192140
# 2  112816  108481  86152  72519  82104  104484  149528  102469  220277
# 3   22944   22468  21107  24589  17132    5507   26971   14986    9466
# 4   94306   85991  64803  56747  65669   99640  117838   85862  191079
#
# [5 rows x 100 columns]

# %%
tmp_df=pd.merge(count_df, lookup_df, on="taxid",how="left")
tmp_df=tmp_df[list(count_df.columns)+["organism_name","ftp_basename","domain","genetic_code"]]
tmp_df=tmp_df[tmp_df["genetic_code"]==11]#!!!TBI!!! failed to handle genetic code=4 for now
print(tmp_df.shape)
tmp_df.head()
# Out:
# (1571, 7)
#      taxid  count_real  count_sim                     organism_name  \
# 0   429572    0.425893   0.427635    Sulfolobus islandicus L.S.2.15
# 1  1434120    0.463257   0.442056      Methanosarcina siciliae T4/M
# 2   188937    0.448898   0.429019    Methanosarcina acetivorans C2A
# 3  1054217    1.094285   0.843878  Thermoplasmatales archaeon BRNA1
# 4  1434123    0.410412   0.401882    Methanosarcina vacuolata Z-761
#
#                  ftp_basename   domain  genetic_code
# 0   GCF_000022385.1_ASM2238v1  archaea            11
# 1  GCF_000970085.1_ASM97008v1  archaea            11
# 2    GCF_000007345.1_ASM734v1  archaea            11
# 3  GCF_000350305.1_ASM35030v1  archaea            11
# 4  GCF_000969905.1_ASM96990v1  archaea            11

# %%
myplot(tmp_df[tmp_df["domain"]=="archaea"])

# %%
out_df=pd.merge(tmp_df, comp_df, on="ftp_basename", how="left")
out_df=out_df[list(tmp_df.columns)+["G+C"]]
print(out_df.shape)
out_df.head()
# Out:
# (1571, 8)
#      taxid  count_real  count_sim                     organism_name  \
# 0   429572    0.425893   0.427635    Sulfolobus islandicus L.S.2.15
# 1  1434120    0.463257   0.442056      Methanosarcina siciliae T4/M
# 2   188937    0.448898   0.429019    Methanosarcina acetivorans C2A
# 3  1054217    1.094285   0.843878  Thermoplasmatales archaeon BRNA1
# 4  1434123    0.410412   0.401882    Methanosarcina vacuolata Z-761
#
#                  ftp_basename   domain  genetic_code       G+C
# 0   GCF_000022385.1_ASM2238v1  archaea            11  0.351110
# 1  GCF_000970085.1_ASM97008v1  archaea            11  0.429404
# 2    GCF_000007345.1_ASM734v1  archaea            11  0.426809
# 3  GCF_000350305.1_ASM35030v1  archaea            11  0.583030
# 4  GCF_000969905.1_ASM96990v1  archaea            11  0.397795

# %%
out_df["diff"]=out_df["count_real"]-out_df["count_sim"]

# %%
plt.figure(figsize=(8,8))
sns.regplot("G+C","diff",data=out_df,fit_reg=False)
plt.show()

# %%
g=sns.jointplot("G+C", "diff", data=out_df,stat_func=None)
plt.show()

# %% [markdown]
# ###  found strange bimodel of bacterial G+C...

# %%
sns.distplot(out_df["G+C"], kde=False, bins =50)

# %% [markdown]
# ## Pick species for genome browser

# %%
out_df[(out_df["G+C"]<0.4) & (out_df["diff"]>0.2)]
# Out:
# Empty DataFrame
# Columns: [taxid, count_real, count_sim, organism_name, ftp_basename, domain, genetic_code, G+C, diff]
# Index: []

# %%
out_df[(out_df["diff"]>0.37)]
# Out:
#        taxid  count_real  count_sim                   organism_name  \
# 723   322710    1.566322   1.154877       Azotobacter vinelandii DJ
# 759    28095    1.725587   1.349730           Burkholderia gladioli
# 1011  679935    1.210287   0.815757  Alistipes finegoldii DSM 17242
#
#                     ftp_basename    domain  genetic_code       G+C      diff
# 723    GCF_000021045.1_ASM2104v1  bacteria            11  0.656755  0.411445
# 759   GCF_000959725.1_ASM95972v1  bacteria            11  0.678557  0.375857
# 1011  GCF_000265365.1_ASM26536v1  bacteria            11  0.566457  0.394531
